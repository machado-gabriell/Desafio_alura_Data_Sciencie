# %% [markdown]
# <a href="https://colab.research.google.com/github/machado-gabriell/Desafio_alura_Data_Sciencie/blob/main/Desafio_alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importação dos dados

# %%
import pandas as pd
dados = pd.read_csv('dados_juntos.csv')
dados
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0            26.0        84996.0                  Rent                0.0
# 1            24.0        55782.0                  Rent                3.0
# 2            25.0       125000.0                   Own                9.0
# 3            23.0        44340.0                   Own                0.0
# 4            23.0        48000.0              Mortgage                5.0
# ...           ...            ...                   ...                ...
# 34496        21.0       120000.0                  Rent                4.0
# 34497        22.0        87000.0                  Rent                5.0
# 34498        27.0        69996.0                  Rent                1.0
# 34499        23.0       100000.0              Mortgage                7.0
# 34500        41.0       121200.0                  Rent                1.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0                Medical          B     9000.0          11.26          0.0
# 1        Homeimprovement          A    17000.0           7.51          0.0
# 2               Personal          B    25000.0          10.59          0.0
# 3                Venture          C     3000.0          12.98          0.0
# 4              Education          C     5000.0          13.99          0.0
# ...                  ...        ...        ...            ...          ...
# 34496  Debtconsolidation          B    10000.0           9.99          0.0
# 34497  Debtconsolidation          C    20000.0          13.85          0.0
# 34498           Personal          B     6000.0          11.86          0.0
# 34499            Medical          B    25000.0          11.71          0.0
# 34500            Venture          A    10000.0           6.03          0.0
#
#        loan_percent_income cb_person_default_on_file  \
# 0                     0.11                         N
# 1                     0.30                         N
# 2                     0.20                         N
# 3                     0.07                         Y
# 4                     0.10                         Y
# ...                    ...                       ...
# 34496                 0.08                         N
# 34497                 0.23                         N
# 34498                 0.09                         N
# 34499                 0.25                         N
# 34500                 0.08                         N
#
#        cb_person_cred_hist_length
# 0                             2.0
# 1                             2.0
# 2                             2.0
# 3                             3.0
# 4                             2.0
# ...                           ...
# 34496                         3.0
# 34497                         4.0
# 34498                         6.0
# 34499                         3.0
# 34500                        13.0
#
# [34501 rows x 12 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Dicionário de dados por tabela
#
# ### dados_mutuarios
#
# Tabela contendo os dados pessoais de cada solicitante
#
# | Feature | Característica |
# | --- | --- |
# |`person_id`|ID da pessoa solicitante|
# | `person_age` | Idade da pessoa - em anos - que solicita empréstimo |
# | `person_income` | Salário anual da pessoa solicitante |
# | `person_home_ownership` | Situação da propriedade que a pessoa possui: *Alugada* (`Rent`), *Própria* (`Own`), *Hipotecada* (`Mortgage`) e *Outros casos* (`Other`) |
# | `person_emp_length` | Tempo - em anos - que a pessoa trabalhou |
#
# ### emprestimos
#
# Tabela contendo as informações do empréstimo solicitado
#
# | Feature | Característica |
# | --- | --- |
# |`loan_id`|ID da solicitação de empréstico de cada solicitante|
# | `loan_intent` | Motivo do empréstimo: *Pessoal* (`Personal`), *Educativo* (`Education`), *Médico* (`Medical`), *Empreendimento* (`Venture`), *Melhora do lar* (`Homeimprovement`), *Pagamento de débitos* (`Debtconsolidation`) |
# | `loan_grade` | Pontuação de empréstimos, por nível variando de `A` a `G` |
# | `loan_amnt` | Valor total do empréstimo solicitado |
# | `loan_int_rate` | Taxa de juros |
# | `loan_status` | Possibilidade de inadimplência |
# | `loan_percent_income` | Renda percentual entre o *valor total do empréstimo* e o *salário anual* |
#
#
# ### historicos_banco
#
# Histório de emprétimos de cada cliente
#
# | Feature | Característica |
# | --- | --- |
# |`cb_id`|ID do histórico de cada solicitante|
# | `cb_person_default_on_file` | Indica se a pessoa já foi inadimplente: sim (`Y`,`YES`) e não (`N`,`NO`) |
# | `cb_person_cred_hist_length` | Tempo - em anos - desde a primeira solicitação de crédito ou aquisição de um cartão de crédito |

# %% [markdown]
# Traduzindo colunas

# %%
novas_colunas = {
    'person_age' : 'idade_pessoa',
    'person_income' : 'renda_anual_pessoal',
    'person_home_ownership' : 'situacao_propriedade',
    'person_emp_length' : 'tempo_trabalho_anos',
    'loan_intent' : 'motivo_emprestimo',
    'loan_grade' : 'pontuacao_emprestimo',
    'loan_amnt' : 'valor_total_emprestimo',
    'loan_int_rate' : 'taxa_juros',
    'loan_status' : 'possibilidade_inadimplencia',
    'loan_percent_income' : 'renda_percentual',
    'cb_person_default_on_file' : 'inadimplente_historico',
    'cb_person_cred_hist_length' : 'tempo_credito_anos'
}

# %%
dados.rename(columns=novas_colunas, inplace=True)

# %% [markdown]
# # Análise de dados

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34501 entries, 0 to 34500
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   idade_pessoa                 34177 non-null  float64
#  1   renda_anual_pessoal          34162 non-null  float64
#  2   situacao_propriedade         34170 non-null  object
#  3   tempo_trabalho_anos          33247 non-null  float64
#  4   motivo_emprestimo            34186 non-null  object
#  5   pontuacao_emprestimo         34188 non-null  object
#  6   valor_total_emprestimo       34170 non-null  float64
#  7   taxa_juros                   30871 non-null  float64
#  8   possibilidade_inadimplencia  34158 non-null  float64
#  9   renda_percentual             34182 non-null  float64
#  10  inadimplente_historico       34131 non-null  object
#  11  tempo_credito_anos           34497 non-null  float64
# dtypes: float64(8), object(4)
# memory usage: 3.2+ MB

# %%
dados.describe()
#Nota: Possui valores inesperados em idade e tempo de trabalho
# Out:
#        idade_pessoa  renda_anual_pessoal  tempo_trabalho_anos  \
# count  28638.000000         2.863800e+04         28638.000000
# mean      27.727216         6.664937e+04             4.788672
# std        6.310441         6.235645e+04             4.154627
# min       20.000000         4.000000e+03             0.000000
# 25%       23.000000         3.948000e+04             2.000000
# 50%       26.000000         5.595600e+04             4.000000
# 75%       30.000000         8.000000e+04             7.000000
# max      144.000000         6.000000e+06           123.000000
#
#        valor_total_emprestimo    taxa_juros  possibilidade_inadimplencia  \
# count            28638.000000  28638.000000                 28638.000000
# mean              9656.493121     11.039867                     0.216600
# std               6329.683361      3.229372                     0.411935
# min                500.000000      5.420000                     0.000000
# 25%               5000.000000      7.900000                     0.000000
# 50%               8000.000000     10.990000                     0.000000
# 75%              12500.000000     13.480000                     0.000000
# max              35000.000000     23.220000                     1.000000
#
#        renda_percentual  tempo_credito_anos
# count      28638.000000        28638.000000
# mean           0.169488            5.793736
# std            0.106393            4.038483
# min            0.000000            2.000000
# 25%            0.090000            3.000000
# 50%            0.150000            4.000000
# 75%            0.230000            8.000000
# max            0.830000           30.000000

# %%
dados['pontuacao_emprestimo'].unique()
# Out:
# array(['B', 'A', 'C', 'E', 'D', nan, 'F', 'G'], dtype=object)

# %%
dados['motivo_emprestimo'].unique()
# Out:
# array(['Medical', 'Homeimprovement', 'Personal', 'Venture', 'Education',
#        'Debtconsolidation', nan], dtype=object)

# %%
dados['situacao_propriedade'].unique()
# Out:
# array(['Rent', 'Own', 'Mortgage', nan, 'Other'], dtype=object)

# %%
dados['inadimplente_historico'].unique()
# Out:
# array(['N', 'Y', nan], dtype=object)

# %%
# Out:
#        idade_pessoa  renda_anual_pessoal situacao_propriedade  \
# 0              26.0              84996.0                 Rent
# 1              24.0              55782.0                 Rent
# 2              25.0             125000.0                  Own
# 3              23.0              44340.0                  Own
# 4              23.0              48000.0             Mortgage
# ...             ...                  ...                  ...
# 34496          21.0             120000.0                 Rent
# 34497          22.0              87000.0                 Rent
# 34498          27.0              69996.0                 Rent
# 34499          23.0             100000.0             Mortgage
# 34500          41.0             121200.0                 Rent
#
#        tempo_trabalho_anos  motivo_emprestimo pontuacao_emprestimo  \
# 0                      0.0            Medical                    B
# 1                      3.0    Homeimprovement                    A
# 2                      9.0           Personal                    B
# 3                      0.0            Venture                    C
# 4                      5.0          Education                    C
# ...                    ...                ...                  ...
# 34496                  4.0  Debtconsolidation                    B
# 34497                  5.0  Debtconsolidation                    C
# 34498                  1.0           Personal                    B
# 34499                  7.0            Medical                    B
# 34500                  1.0            Venture                    A
#
#        valor_total_emprestimo  taxa_juros  possibilidade_inadimplencia  \
# 0                      9000.0       11.26                          0.0
# 1                     17000.0        7.51                          0.0
# 2                     25000.0       10.59                          0.0
# 3                      3000.0       12.98                          0.0
# 4                      5000.0       13.99                          0.0
# ...                       ...         ...                          ...
# 34496                 10000.0        9.99                          0.0
# 34497                 20000.0       13.85                          0.0
# 34498                  6000.0       11.86                          0.0
# 34499                 25000.0       11.71                          0.0
# 34500                 10000.0        6.03                          0.0
#
#        renda_percentual inadimplente_historico  tempo_credito_anos
# 0                  0.11                      N                 2.0
# 1                  0.30                      N                 2.0
# 2                  0.20                      N                 2.0
# 3                  0.07                      Y                 3.0
# 4                  0.10                      Y                 2.0
# ...                 ...                    ...                 ...
# 34496              0.08                      N                 3.0
# 34497              0.23                      N                 4.0
# 34498              0.09                      N                 6.0
# 34499              0.25                      N                 3.0
# 34500              0.08                      N                13.0
#
# [34501 rows x 12 columns]

# %%
dados['possibilidade_inadimplencia'].value_counts(normalize = True)
# Out:
# possibilidade_inadimplencia
# 0.0    0.781808
# 1.0    0.218192
# Name: proportion, dtype: float64

# %%
# Avaliar qtd de registros(linhas) no df
dados.shape[0]
# Out:
# 28638

# %%
#Avaliar qtd de valores nulos
dados.isna().sum()
# Out:
# idade_pessoa                    324
# renda_anual_pessoal             339
# situacao_propriedade            331
# tempo_trabalho_anos            1254
# motivo_emprestimo               315
# pontuacao_emprestimo            313
# valor_total_emprestimo          331
# taxa_juros                     3630
# possibilidade_inadimplencia     343
# renda_percentual                319
# inadimplente_historico          370
# tempo_credito_anos                4
# dtype: int64

# %%
#Apagar valores nulos
dados.dropna(inplace=True)

# %%
dados.shape[0]
# Out:
# 28638

# %%
dados.to_csv('dados_juntos_1.csv', index=False)

# %%
from google.colab import files
 files.download('dados_juntos_1.csv')
# Out:
#   File "<ipython-input-15-8804d715f07a>", line 2
#     files.download('dados_juntos_1.csv')
#     ^
# IndentationError: unexpected indent

# %%
import pandas as pd
dados = pd.read_csv('dados_juntos_1.csv')
dados
# Out:
#        idade_pessoa  renda_anual_pessoal situacao_propriedade  \
# 0              26.0              84996.0                 Rent
# 1              24.0              55782.0                 Rent
# 2              25.0             125000.0                  Own
# 3              23.0              44340.0                  Own
# 4              23.0              48000.0             Mortgage
# ...             ...                  ...                  ...
# 28633          21.0             120000.0                 Rent
# 28634          22.0              87000.0                 Rent
# 28635          27.0              69996.0                 Rent
# 28636          23.0             100000.0             Mortgage
# 28637          41.0             121200.0                 Rent
#
#        tempo_trabalho_anos  motivo_emprestimo pontuacao_emprestimo  \
# 0                      0.0            Medical                    B
# 1                      3.0    Homeimprovement                    A
# 2                      9.0           Personal                    B
# 3                      0.0            Venture                    C
# 4                      5.0          Education                    C
# ...                    ...                ...                  ...
# 28633                  4.0  Debtconsolidation                    B
# 28634                  5.0  Debtconsolidation                    C
# 28635                  1.0           Personal                    B
# 28636                  7.0            Medical                    B
# 28637                  1.0            Venture                    A
#
#        valor_total_emprestimo  taxa_juros  possibilidade_inadimplencia  \
# 0                      9000.0       11.26                          0.0
# 1                     17000.0        7.51                          0.0
# 2                     25000.0       10.59                          0.0
# 3                      3000.0       12.98                          0.0
# 4                      5000.0       13.99                          0.0
# ...                       ...         ...                          ...
# 28633                 10000.0        9.99                          0.0
# 28634                 20000.0       13.85                          0.0
# 28635                  6000.0       11.86                          0.0
# 28636                 25000.0       11.71                          0.0
# 28637                 10000.0        6.03                          0.0
#
#        renda_percentual inadimplente_historico  tempo_credito_anos
# 0                  0.11                      N                 2.0
# 1                  0.30                      N                 2.0
# 2                  0.20                      N                 2.0
# 3                  0.07                      Y                 3.0
# 4                  0.10                      Y                 2.0
# ...                 ...                    ...                 ...
# 28633              0.08                      N                 3.0
# 28634              0.23                      N                 4.0
# 28635              0.09                      N                 6.0
# 28636              0.25                      N                 3.0
# 28637              0.08                      N                13.0
#
# [28638 rows x 12 columns]

# %%
# Avaliar outliears (idade, tempo de trabalho)
dados[dados['idade_pessoa'] > 100]
# Out:
#        idade_pessoa  renda_anual_pessoal situacao_propriedade  \
# 147           144.0             200000.0             Mortgage
# 9587          144.0             250000.0                 Rent
# 25254         144.0            6000000.0             Mortgage
# 27471         123.0              80004.0                 Rent
#
#        tempo_trabalho_anos motivo_emprestimo pontuacao_emprestimo  \
# 147                    4.0         Education                    B
# 9587                   4.0           Venture                    C
# 25254                 12.0          Personal                    C
# 27471                  2.0         Education                    B
#
#        valor_total_emprestimo  taxa_juros  possibilidade_inadimplencia  \
# 147                    6000.0       11.86                          0.0
# 9587                   4800.0       13.57                          0.0
# 25254                  5000.0       12.73                          0.0
# 27471                 20400.0       10.25                          0.0
#
#        renda_percentual inadimplente_historico  tempo_credito_anos
# 147                0.03                      N                 2.0
# 9587               0.02                      N                 3.0
# 25254              0.00                      N                25.0
# 27471              0.25                      N                 3.0

# %%
dados[dados['tempo_trabalho_anos'] > 50]
# Out:
#       idade_pessoa  renda_anual_pessoal situacao_propriedade  \
# 5836          22.0              59000.0                 Rent
# 7410          21.0             192000.0             Mortgage
#
#       tempo_trabalho_anos motivo_emprestimo pontuacao_emprestimo  \
# 5836                123.0          Personal                    D
# 7410                123.0           Venture                    A
#
#       valor_total_emprestimo  taxa_juros  possibilidade_inadimplencia  \
# 5836                 35000.0       16.02                          1.0
# 7410                 20000.0        6.54                          0.0
#
#       renda_percentual inadimplente_historico  tempo_credito_anos
# 5836              0.59                      Y                 3.0
# 7410              0.10                      N                 4.0

# %%
# Excluir outliears
dados = dados[(dados['idade_pessoa'] < 110) & (dados['tempo_trabalho_anos'] < 100)]
# Out:
#        idade_pessoa  renda_anual_pessoal situacao_propriedade  \
# 0              26.0              84996.0                 Rent
# 1              24.0              55782.0                 Rent
# 2              25.0             125000.0                  Own
# 3              23.0              44340.0                  Own
# 4              23.0              48000.0             Mortgage
# ...             ...                  ...                  ...
# 28633          21.0             120000.0                 Rent
# 28634          22.0              87000.0                 Rent
# 28635          27.0              69996.0                 Rent
# 28636          23.0             100000.0             Mortgage
# 28637          41.0             121200.0                 Rent
#
#        tempo_trabalho_anos  motivo_emprestimo pontuacao_emprestimo  \
# 0                      0.0            Medical                    B
# 1                      3.0    Homeimprovement                    A
# 2                      9.0           Personal                    B
# 3                      0.0            Venture                    C
# 4                      5.0          Education                    C
# ...                    ...                ...                  ...
# 28633                  4.0  Debtconsolidation                    B
# 28634                  5.0  Debtconsolidation                    C
# 28635                  1.0           Personal                    B
# 28636                  7.0            Medical                    B
# 28637                  1.0            Venture                    A
#
#        valor_total_emprestimo  taxa_juros  possibilidade_inadimplencia  \
# 0                      9000.0       11.26                          0.0
# 1                     17000.0        7.51                          0.0
# 2                     25000.0       10.59                          0.0
# 3                      3000.0       12.98                          0.0
# 4                      5000.0       13.99                          0.0
# ...                       ...         ...                          ...
# 28633                 10000.0        9.99                          0.0
# 28634                 20000.0       13.85                          0.0
# 28635                  6000.0       11.86                          0.0
# 28636                 25000.0       11.71                          0.0
# 28637                 10000.0        6.03                          0.0
#
#        renda_percentual inadimplente_historico  tempo_credito_anos
# 0                  0.11                      N                 2.0
# 1                  0.30                      N                 2.0
# 2                  0.20                      N                 2.0
# 3                  0.07                      Y                 3.0
# 4                  0.10                      Y                 2.0
# ...                 ...                    ...                 ...
# 28633              0.08                      N                 3.0
# 28634              0.23                      N                 4.0
# 28635              0.09                      N                 6.0
# 28636              0.25                      N                 3.0
# 28637              0.08                      N                13.0
#
# [28632 rows x 12 columns]

# %%
# Substituir o tipo da coluna idade de float para int
dados['idade_pessoa'] = dados['idade_pessoa'].astype(int)

# %% [markdown]
# #Tratamentos dos dados

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28632 entries, 0 to 28637
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   idade_pessoa                 28632 non-null  int64
#  1   renda_anual_pessoal          28632 non-null  float64
#  2   situacao_propriedade         28632 non-null  object
#  3   tempo_trabalho_anos          28632 non-null  float64
#  4   motivo_emprestimo            28632 non-null  object
#  5   pontuacao_emprestimo         28632 non-null  object
#  6   valor_total_emprestimo       28632 non-null  float64
#  7   taxa_juros                   28632 non-null  float64
#  8   possibilidade_inadimplencia  28632 non-null  float64
#  9   renda_percentual             28632 non-null  float64
#  10  inadimplente_historico       28632 non-null  object
#  11  tempo_credito_anos           28632 non-null  float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 2.8+ MB

# %%
# Avaliar correlação dos dados
dados_correlacao = dados.select_dtypes(include=['int64','float64'])
dados_correlacao
# Out:
#        idade_pessoa  renda_anual_pessoal  tempo_trabalho_anos  \
# 0                26              84996.0                  0.0
# 1                24              55782.0                  3.0
# 2                25             125000.0                  9.0
# 3                23              44340.0                  0.0
# 4                23              48000.0                  5.0
# ...             ...                  ...                  ...
# 28633            21             120000.0                  4.0
# 28634            22              87000.0                  5.0
# 28635            27              69996.0                  1.0
# 28636            23             100000.0                  7.0
# 28637            41             121200.0                  1.0
#
#        valor_total_emprestimo  taxa_juros  possibilidade_inadimplencia  \
# 0                      9000.0       11.26                          0.0
# 1                     17000.0        7.51                          0.0
# 2                     25000.0       10.59                          0.0
# 3                      3000.0       12.98                          0.0
# 4                      5000.0       13.99                          0.0
# ...                       ...         ...                          ...
# 28633                 10000.0        9.99                          0.0
# 28634                 20000.0       13.85                          0.0
# 28635                  6000.0       11.86                          0.0
# 28636                 25000.0       11.71                          0.0
# 28637                 10000.0        6.03                          0.0
#
#        renda_percentual  tempo_credito_anos
# 0                  0.11                 2.0
# 1                  0.30                 2.0
# 2                  0.20                 2.0
# 3                  0.07                 3.0
# 4                  0.10                 2.0
# ...                 ...                 ...
# 28633              0.08                 3.0
# 28634              0.23                 4.0
# 28635              0.09                 6.0
# 28636              0.25                 3.0
# 28637              0.08                13.0
#
# [28632 rows x 8 columns]

# %%
dados_correlacao.corr()
# Out:
#                              idade_pessoa  renda_anual_pessoal  \
# idade_pessoa                     1.000000             0.141471
# renda_anual_pessoal              0.141471             1.000000
# tempo_trabalho_anos              0.176054             0.160952
# valor_total_emprestimo           0.056061             0.324766
# taxa_juros                       0.010370            -0.003767
# possibilidade_inadimplencia     -0.022498            -0.167028
# renda_percentual                -0.039476            -0.297635
# tempo_credito_anos               0.877581             0.122787
#
#                              tempo_trabalho_anos  valor_total_emprestimo  \
# idade_pessoa                            0.176054                0.056061
# renda_anual_pessoal                     0.160952                0.324766
# tempo_trabalho_anos                     1.000000                0.108390
# valor_total_emprestimo                  0.108390                1.000000
# taxa_juros                             -0.058263                0.145895
# possibilidade_inadimplencia            -0.086486                0.113363
# renda_percentual                       -0.060099                0.577197
# tempo_credito_anos                      0.151571                0.045580
#
#                              taxa_juros  possibilidade_inadimplencia  \
# idade_pessoa                   0.010370                    -0.022498
# renda_anual_pessoal           -0.003767                    -0.167028
# tempo_trabalho_anos           -0.058263                    -0.086486
# valor_total_emprestimo         0.145895                     0.113363
# taxa_juros                     1.000000                     0.339307
# possibilidade_inadimplencia    0.339307                     1.000000
# renda_percentual               0.123401                     0.379534
# tempo_credito_anos             0.015330                    -0.015575
#
#                              renda_percentual  tempo_credito_anos
# idade_pessoa                        -0.039476            0.877581
# renda_anual_pessoal                 -0.297635            0.122787
# tempo_trabalho_anos                 -0.060099            0.151571
# valor_total_emprestimo               0.577197            0.045580
# taxa_juros                           0.123401            0.015330
# possibilidade_inadimplencia          0.379534           -0.015575
# renda_percentual                     1.000000           -0.029814
# tempo_credito_anos                  -0.029814            1.000000
